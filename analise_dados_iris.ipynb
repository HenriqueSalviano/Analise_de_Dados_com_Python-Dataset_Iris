# %% [markdown]
# #### Análise de Dados com Python- Analisando o dataset Iris

# %% [markdown]
# Pacotes que iremos utilizar:

# %%
import piplite
await piplite.install(['seaborn'])

# %%
import seaborn as sns

# %%
import pandas as pd
from pathlib import Path

import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn import datasets

# %% [markdown]
# ### Análise

# %%
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data)
iris_df['species']= iris.target

iris_df.columns=['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid', 'species']
#iris_df.dropna(how="all", inplace=True) # remove any empty lines

iris_df['species'] = iris_df['species'].replace([0,1,2],['setosa','versicolor','virginica']) 

iris_df

# %%
iris_df.describe()

# %%
iris_df['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
sns.pairplot(iris_df,hue = 'species')

# %%
sns.boxplot(data = iris_df)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data = iris_df['sepal_len'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data = iris_df['sepal_wid'])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(matriz_corr, annot = True, cmap = 'RdBu_r')
# Out:
# <AxesSubplot:>
